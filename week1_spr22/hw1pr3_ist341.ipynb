# %% [markdown]
# #### Welcome to ist341, week 1 PythonBat problem!
#
# This notebook has a single cell, to hold your [PythonBat](https://codingbat.com/python) solutions:
# + Here is the [PythonBat problem page description and explanation](https://www.cs.hmc.edu/twiki/bin/view/CS5Fall2020/PythonBatFunctionsGold)
# + You _should_ include your functions here, pasted in the cell below
# + However, you _don't_ need doctrings
# + nor do you need tests (PythonBat itself will run all of the tests!)
#
# Do be sure to "share" your PythonBat results with me at <tt>dodds@cs.hmc.edu</tt>
#
# Remember that the goal is not all of the problems, it's
# + half (25) of the problems - your choice - from the 51 non-looping problems at [PythonBat](https://codingbat.com/python)
#   + Twelve (12) Warmup-1 problems
#   + Eleven (11) String-1 problems
#   + Twelve (12) List-1 problems
#   + Nine (9) Logic-1 problems
#   + Seven (7) Logic-2 problems
#
# <br>
#
# + Any of the other half (26, in fact) can be done for extra-credit.
# + Warning:  PythonBat can be pretty addictive :-)
# <hr>

# %%
#
# paste your PythonBat functions into this cell:
#

def front3(str):
  n = len(str)
  if n <= 3:
    return str * 3
  else: return str[0:3] * 3


def sleep_in(weekday, vacation):
  if weekday == False or vacation == True:
    return True
  else:
    return False

def monkey_trouble(a_smile, b_smile):
  if a_smile == True and b_smile == True:
    return True
  elif a_smile == False and b_smile == False:
    return True
  else: return False
    
def sum_double(a, b):
  if a == b:
    return (a+b)*2
  else: return a+b
    
def diff21(n):
  if n <= 21:
    return abs(21-n)
  else: return 2*abs(21-n)
    
def parrot_trouble(talking, hour):
  if talking == True:
    if hour < 7 or hour > 20:
      return True
    else:
      return False
  else: return False
    
def makes10(a, b):
  if a+b == 10 or a == 10 or b == 10:
    return True
  else: return False
    
def near_hundred(n):
  if abs(100-n) <= 10 or abs(200-n) <= 10:
    return True
  else: return False
    
def pos_neg(a, b, negative):
  if negative == True:
    if a < 0 and b < 0:
      return True
    else: return False
  else:
    if a * b < 0:
      return True
    else: return False
    
def not_string(str):
  if 'not' == str[0:3]:
    return str
  else: return 'not ' + str
    
def missing_char(str, n):
  return str[0:n] + str[n+1:]

def hello_name(name):
  return 'Hello ' + name + '!'

def make_abba(a, b):
  return a + b + b + a

def make_out_word(out, word):
  return out[0:2] + word + out[2:]

def extra_end(str):
  return str[-2:] * 3

def first_two(str):
  n = len(str)
  if n <= 2:
    return str
  else:
    return str[0:2]

def first_half(str):
  n = len(str)
  return str[0:n/2]

def without_end(str):
  return str[1:-1]

def combo_string(a, b):
  m = len(a)
  n = len(b)
  if m < n:
    return a + b + a
  else: return b + a + b
    
def non_start(a, b):
  return a[1:] + b[1:]

def left2(str):
    return str[2:] + str[0:2]

def has23(nums):
  if 2 in nums or 3 in nums:
    return True
  else: return False
    
def make_ends(nums):
  test = []
  test.append(nums[0])
  test.append(nums[-1])
  return test

def middle_way(a, b):
  test = []
  test.append(a[1])
  test.append(b[1])
  return test

def sum2(nums):
  n = len(nums)
  if n < 2:
    return sum(nums)
  else: return sum(nums[0:2])
    
def max_end3(nums):
  if nums[0] < nums[-1]:
    return nums[-1:] * 3
  else:
    return nums[0:1] * 3

def reverse3(nums):
  j = len(nums)-1
  i = 0
  while i < j:
    nums[i], nums[j] = nums[j], nums[i]
    i += 1
    j -= 1
  return nums

def rotate_left3(nums):
  test = nums[1:]
  test.append(nums[0])
  return test

def sum3(nums):
  return sum(nums)

def common_end(a, b):
  if a[0] == b[0] or a[-1] == b[-1]:
    return True
  else: return False
    
def make_pi():
  return [3,1,4]

def same_first_last(nums):
  if len(nums) < 1:
    return False
  else:
    if nums[0] == nums[-1]:
      return True
    else: return False
    
def first_last6(nums):
  if nums[0] == 6 or nums[-1] == 6:
    return True
  else: return False
    
def near_ten(num):
  n = num % 10
  if n <=2 or n >=8:
    return True
  else: return False

def in1to10(n, outside_mode):
  if outside_mode == False:
    if n >=1 and n <= 10:
      return True
    else: return False
  else:
    if n >1 and n < 10:
      return False
    else: return True
    
def love6(a, b):
  if a == 6 or b == 6 or abs(a-b) == 6 or a+b == 6:
    return True
  else: return False
    
def alarm_clock(day, vacation):
  if vacation == True:
    if day == 0 or day == 6:
      return 'off'
    else: return '10:00'
  else:
    if day == 0 or day == 6:
      return '10:00'
    else: return '7:00'
    
def sorta_sum(a, b):
  n = a + b
  if n >= 10 and n <= 19:
    return 20
  else: return n
    
def caught_speeding(speed, is_birthday):
  if is_birthday == False:
    if speed <= 60:
      return 0
    elif speed > 60 and speed <= 80:
      return 1
    else: return 2
  else:
    if speed <= 65:
      return 0
    elif speed > 65 and speed <= 85:
      return 1
    else: return 2
    
def squirrel_play(temp, is_summer):
  if is_summer == True:
    if temp >= 60 and temp <= 100:
      return True
    else: return False
  else:
    if temp >= 60 and temp <= 90:
      return True
    else: return False
    
def date_fashion(you, date):
  if you >= 8 or date >= 8:
    if you <= 2 or date <= 2:
      return 0
    else: return 2
  elif you <= 2 or date <= 2:
    return 0
  else: return 1
    
def cigar_party(cigars, is_weekend):
  if is_weekend == True:
    if cigars >= 40:
      return True
    else: return False
  else:
    if cigars >= 40 and cigars <= 60:
      return True
    else: return False

# %% [markdown]
# ####  Complete!
# + If you've completed these, go ahead and submit this notebook to our Gradescope site.
