# %% [markdown]
# ### Description of the project

# %% [markdown]
# ### Dataset: https://www.kaggle.com/competitions/jpx-tokyo-stock-exchange-prediction/data

# %%
from IPython import display
display.Image("./competition.png")

# %% [markdown]
# - This is the competition on Kaggle which focuses on predicting Japanese stock price
# - We should use the stock data to predict the target price
# - However, for the project, we would like to start from a simple prediction target instead of directly satisfing the final requirement of the competition
# - We are excited to apply what we learned in the course to the real case!
# - Our big picture is to win the competition!

# %% [markdown]
# ### Python Libraries

# %% [markdown]
# - Numpy
# - Pandas
# - Sklearn
# - Flask

# %% [markdown]
# ### Online Resources

# %% [markdown]
# - competition data description: https://www.kaggle.com/competitions/jpx-tokyo-stock-exchange-prediction/data
# - understanding of the competition: https://www.kaggle.com/code/chumajin/easy-to-understand-the-competition?scriptVersionId=94143164

# %% [markdown]
# ### Proposed Timeline

# %% [markdown]
# #### This week:
# - Data Exploration
# - Front end design
# - Predict target rate is positive or negative

# %% [markdown]
# #### After Presentation:
# - Predict target rate by switiching the rate to multiple classes
# - Predict the exact target rate
# - Finish the front end

# %% [markdown]
# #### Before the end of the project:
# - Submit our result on Kaggle

# %% [markdown]
# ### Overview of the exploration

# %% [markdown]
# - We have understand the dataset and make a clean version on it

# %%
from IPython import display
display.Image("./dataclean.png")

# %% [markdown]
# - We try two kinds of experiments with KNN, DT, RF, and NN
# - First, we use one stock as training data to build the model, and predict other stocks' data to see which one is the least and most modleable
# - Second, we use all of the data to train model and test the model with testing data
# - We also design the front end with Flask
