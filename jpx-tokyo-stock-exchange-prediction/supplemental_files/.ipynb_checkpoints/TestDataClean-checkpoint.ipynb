# %%
# libraries!
import numpy as np      # numpy is Python's "array" library
import pandas as pd     # Pandas is Python's "data" library ("dataframe" == spreadsheet)

# %%
# let's read in our stock data...
# 
# 
filename = 'stock_prices.csv'
df = pd.read_csv(filename)        # encoding="utf-8" et al.
print(f"{filename} : file read into a pandas dataframe.")
# Out:
# stock_prices.csv : file read into a pandas dataframe.

# %%
#
# a dataframe is a "spreadsheet in Python"   (seems to have an extra column!)
#
# let's view it!
df.head()
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211206_1301  2021-12-06            1301  2982.0  2982.0  2965.0  2971.0
# 1  20211206_1332  2021-12-06            1332   592.0   599.0   588.0   589.0
# 2  20211206_1333  2021-12-06            1333  2368.0  2388.0  2360.0  2377.0
# 3  20211206_1375  2021-12-06            1375  1230.0  1239.0  1224.0  1224.0
# 4  20211206_1376  2021-12-06            1376  1339.0  1372.0  1339.0  1351.0
#
#     Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target
# 0     8900               1.0               NaN            False -0.003263
# 1  1360800               1.0               NaN            False -0.008993
# 2   125900               1.0               NaN            False -0.009963
# 3    81100               1.0               NaN            False -0.015032
# 4     6200               1.0               NaN            False  0.002867

# %%
df.tail()
# Out:
#                 RowId        Date  SecuritiesCode    Open    High     Low  \
# 111995  20220228_9990  2022-02-28            9990   511.0   518.0   509.0
# 111996  20220228_9991  2022-02-28            9991   823.0   825.0   814.0
# 111997  20220228_9993  2022-02-28            9993  1600.0  1622.0  1600.0
# 111998  20220228_9994  2022-02-28            9994  2568.0  2568.0  2540.0
# 111999  20220228_9997  2022-02-28            9997   731.0   737.0   726.0
#
#          Close  Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# 111995   516.0  120600               1.0               NaN            False
# 111996   822.0   16200               1.0               NaN            False
# 111997  1600.0    4000               1.0               NaN            False
# 111998  2565.0    9000               1.0               NaN            False
# 111999   734.0  288100               1.0               NaN            False
#
#           Target
# 111995 -0.013592
# 111996 -0.020581
# 111997  0.005762
# 111998 -0.002341
# 111999 -0.030014

# %%
#
# let's look at the dataframe's "info":
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112000 entries, 0 to 111999
# Data columns (total 12 columns):
# RowId               112000 non-null object
# Date                112000 non-null object
# SecuritiesCode      112000 non-null int64
# Open                111716 non-null float64
# High                111716 non-null float64
# Low                 111716 non-null float64
# Close               111716 non-null float64
# Volume              112000 non-null int64
# AdjustmentFactor    112000 non-null float64
# ExpectedDividend    503 non-null float64
# SupervisionFlag     112000 non-null bool
# Target              112000 non-null float64
# dtypes: bool(1), float64(7), int64(2), object(2)
# memory usage: 9.5+ MB

# %%
# Let's look at the dataframe's columns:
df.columns
# Out:
# Index(['RowId', 'Date', 'SecuritiesCode', 'Open', 'High', 'Low', 'Close',
#        'Volume', 'AdjustmentFactor', 'ExpectedDividend', 'SupervisionFlag',
#        'Target'],
#       dtype='object')

# %%
# we can drop a series of data (a row or a column)
# they're indicated by numeric value, row~0, col~1, but let's use readable names instead:
ROW = 0
COLUMN = 1

df_clean1 = df.drop(['RowId', 'SecuritiesCode', 'AdjustmentFactor', 'ExpectedDividend', 'SupervisionFlag'], axis=COLUMN)
df_clean1.head()

# df_clean1 is a new dataframe, without that unwanted column
# Out:
#          Date    Open    High     Low   Close   Volume    Target
# 0  2021-12-06  2982.0  2982.0  2965.0  2971.0     8900 -0.003263
# 1  2021-12-06   592.0   599.0   588.0   589.0  1360800 -0.008993
# 2  2021-12-06  2368.0  2388.0  2360.0  2377.0   125900 -0.009963
# 3  2021-12-06  1230.0  1239.0  1224.0  1224.0    81100 -0.015032
# 4  2021-12-06  1339.0  1372.0  1339.0  1351.0     6200  0.002867

# %%
#
# let's drop _all_ rows with data that is missing/NaN (not-a-number)
df_clean2 = df_clean1.dropna()
df_clean2.info()  # print the info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111716 entries, 0 to 111999
# Data columns (total 7 columns):
# Date      111716 non-null object
# Open      111716 non-null float64
# High      111716 non-null float64
# Low       111716 non-null float64
# Close     111716 non-null float64
# Volume    111716 non-null int64
# Target    111716 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 6.8+ MB

# %%
# Change Date from object to date

df_clean2["Date"] = pd.to_datetime(df_clean2["Date"])
df_clean2.head()
# Out:
# /Users/jason/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Date    Open    High     Low   Close   Volume    Target
# 0 2021-12-06  2982.0  2982.0  2965.0  2971.0     8900 -0.003263
# 1 2021-12-06   592.0   599.0   588.0   589.0  1360800 -0.008993
# 2 2021-12-06  2368.0  2388.0  2360.0  2377.0   125900 -0.009963
# 3 2021-12-06  1230.0  1239.0  1224.0  1224.0    81100 -0.015032
# 4 2021-12-06  1339.0  1372.0  1339.0  1351.0     6200  0.002867

# %%
# Add Date features to the data

df_clean2["Year"] = df_clean2["Date"].dt.year
df_clean2["Month"] = df_clean2["Date"].dt.month
df_clean2["Day"] = df_clean2["Date"].dt.day

df_clean2.head()
# Out:
# /Users/jason/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/jason/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/jason/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#         Date    Open    High     Low   Close   Volume    Target  Year  Month  \
# 0 2021-12-06  2982.0  2982.0  2965.0  2971.0     8900 -0.003263  2021     12
# 1 2021-12-06   592.0   599.0   588.0   589.0  1360800 -0.008993  2021     12
# 2 2021-12-06  2368.0  2388.0  2360.0  2377.0   125900 -0.009963  2021     12
# 3 2021-12-06  1230.0  1239.0  1224.0  1224.0    81100 -0.015032  2021     12
# 4 2021-12-06  1339.0  1372.0  1339.0  1351.0     6200  0.002867  2021     12
#
#    Day
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6

# %%
#Drop Date Column

df_clean3 = df_clean2.drop(['Date'], axis=COLUMN)
df_clean3.head()
# Out:
#      Open    High     Low   Close   Volume    Target  Year  Month  Day
# 0  2982.0  2982.0  2965.0  2971.0     8900 -0.003263  2021     12    6
# 1   592.0   599.0   588.0   589.0  1360800 -0.008993  2021     12    6
# 2  2368.0  2388.0  2360.0  2377.0   125900 -0.009963  2021     12    6
# 3  1230.0  1239.0  1224.0  1224.0    81100 -0.015032  2021     12    6
# 4  1339.0  1372.0  1339.0  1351.0     6200  0.002867  2021     12    6

# %%
df_clean3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111716 entries, 0 to 111999
# Data columns (total 9 columns):
# Open      111716 non-null float64
# High      111716 non-null float64
# Low       111716 non-null float64
# Close     111716 non-null float64
# Volume    111716 non-null int64
# Target    111716 non-null float64
# Year      111716 non-null int64
# Month     111716 non-null int64
# Day       111716 non-null int64
# dtypes: float64(5), int64(4)
# memory usage: 8.5 MB

# %%
# Covert target to two category
# Positive and Negative

def convert_rate(rate):
    """ return the positive and nagative  """

    if rate > 0:
        return 1
    else: return 0

# %%
#
# we can "apply" to a whole column and create a new column
#   it may give a warning, but this is ok...
#

df_clean4 = df_clean3.copy()  # copy everything AND...

# add a new column, 'irisnum'
df_clean4['twoclass'] = df_clean3['Target'].apply(convert_rate)

# let's see...
df_clean4.head()
# Out:
#      Open    High     Low   Close   Volume    Target  Year  Month  Day  \
# 0  2982.0  2982.0  2965.0  2971.0     8900 -0.003263  2021     12    6
# 1   592.0   599.0   588.0   589.0  1360800 -0.008993  2021     12    6
# 2  2368.0  2388.0  2360.0  2377.0   125900 -0.009963  2021     12    6
# 3  1230.0  1239.0  1224.0  1224.0    81100 -0.015032  2021     12    6
# 4  1339.0  1372.0  1339.0  1351.0     6200  0.002867  2021     12    6
#
#    twoclass
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1

# %%
# Let's see amount of the two categories

df_clean4.twoclass.hist()
# Out:
# <AxesSubplot:>

# %%
# Exact number of each class

df_clean4.groupby('twoclass').count()
# Out:
#            Open   High    Low  Close  Volume  Target   Year  Month    Day
# twoclass
# 0         59655  59655  59655  59655   59655   59655  59655  59655  59655
# 1         52061  52061  52061  52061   52061   52061  52061  52061  52061

# %%
# Covert target to ten category

def convert_rate_multiclass(rate):
    """ return the classes  """

    if rate < -0.025:
        return 0
    elif rate >= -0.025 and rate < -0.015:
        return 1
    elif rate >= -0.015 and rate < -0.01:
        return 2
    elif rate >= -0.01 and rate < -0.005:
        return 3
    elif rate >= -0.005 and rate <= 0:
        return 4
    elif rate > 0 and rate < 0.005:
        return 5
    elif rate >= 0.005 and rate < 0.01:
        return 6
    elif rate >= 0.01 and rate < 0.015:
        return 7
    elif rate >= 0.015 and rate < 0.025:
        return 8
    else: return 9

# %%
#
# we can "apply" to a whole column and create a new column
#   it may give a warning, but this is ok...
#

df_clean5 = df_clean4.copy()  # copy everything AND...

# add a new column, 'irisnum'
df_clean5['multiclasses'] = df_clean4['Target'].apply(convert_rate_multiclass)

# let's see...
df_clean5.head()
# Out:
#      Open    High     Low   Close   Volume    Target  Year  Month  Day  \
# 0  2982.0  2982.0  2965.0  2971.0     8900 -0.003263  2021     12    6
# 1   592.0   599.0   588.0   589.0  1360800 -0.008993  2021     12    6
# 2  2368.0  2388.0  2360.0  2377.0   125900 -0.009963  2021     12    6
# 3  1230.0  1239.0  1224.0  1224.0    81100 -0.015032  2021     12    6
# 4  1339.0  1372.0  1339.0  1351.0     6200  0.002867  2021     12    6
#
#    twoclass  multiclasses
# 0         0             4
# 1         0             3
# 2         0             3
# 3         0             1
# 4         1             5

# %%
# Let's see amount of the two categories

df_clean5.multiclasses.hist()
# Out:
# <AxesSubplot:>

# %%
# Exact number of each class

df_clean5.groupby('multiclasses').count()
# Out:
#                Open   High    Low  Close  Volume  Target   Year  Month    Day  \
# multiclasses
# 0             12621  12621  12621  12621   12621   12621  12621  12621  12621
# 1             10960  10960  10960  10960   10960   10960  10960  10960  10960
# 2              8657   8657   8657   8657    8657    8657   8657   8657   8657
# 3             11483  11483  11483  11483   11483   11483  11483  11483  11483
# 4             15934  15934  15934  15934   15934   15934  15934  15934  15934
# 5             12207  12207  12207  12207   12207   12207  12207  12207  12207
# 6             11120  11120  11120  11120   11120   11120  11120  11120  11120
# 7              8464   8464   8464   8464    8464    8464   8464   8464   8464
# 8             10505  10505  10505  10505   10505   10505  10505  10505  10505
# 9              9765   9765   9765   9765    9765    9765   9765   9765   9765
#
#               twoclass
# multiclasses
# 0                12621
# 1                10960
# 2                 8657
# 3                11483
# 4                15934
# 5                12207
# 6                11120
# 7                 8464
# 8                10505
# 9                 9765

# %%
#
# That's it!  Then, and write it out to stocks_cleaned.csv

# We'll construct the new filename:
cleaned_filename = "stocks_cleaned_test.csv"  # name-creating
print(f"cleaned_filename is {cleaned_filename}")

# Now, save
df_clean5.to_csv(cleaned_filename, index_label=False)  # no "index" column...
# Out:
# cleaned_filename is stocks_cleaned_test.csv
